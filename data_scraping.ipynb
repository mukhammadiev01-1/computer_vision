# %% [markdown]
# <a href="https://colab.research.google.com/github/mukhammadiev01-1/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.3-py3-none-any.whl.metadata (3.9 kB)
# Downloading bing_image_downloader-1.1.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.3

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
)
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.freeiconspng.com/uploads/facebook-png-icon-follow-us-facebook-1.png
# [!] Issue getting: https://www.freeiconspng.com/uploads/facebook-png-icon-follow-us-facebook-1.png
# [!] Error:: Invalid image, not saving https://www.freeiconspng.com/uploads/facebook-png-icon-follow-us-facebook-1.png
# [%] No new images found, stopping.
#
#
# [%] Done. Downloaded 0 images.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://cookingorgeous.com/wp-content/uploads/2021/06/lamb-shish-kebab-20.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.recipetineats.com/wp-content/uploads/2017/11/Chicken-Doner-Kebab-1-SQ.jpg?resize=100
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://www.giverecipe.com/wp-content/uploads/2023/03/Chicken-Doner-Kebab-Recipe.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://www.unicornsinthekitchen.com/wp-content/uploads/2022/11/Doner-kebab-sq.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://www.jocooks.com/wp-content/uploads/2023/04/chicken-doner-kebab-1.jpg
# [!] Issue getting: https://www.jocooks.com/wp-content/uploads/2023/04/chicken-doner-kebab-1.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #5 from https://www.takeaway.com/foodwiki/uploads/sites/11/2019/08/doner_kebab_2-1080x960.jpg
# [!] Issue getting: https://www.takeaway.com/foodwiki/uploads/sites/11/2019/08/doner_kebab_2-1080x960.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #5 from https://www.thespruceeats.com/thmb/3aS-MqMydQjW1n7RBGWNVYQagIo=/4494x3000/filters:fill(auto,1)/basic-turkish-chicken-kebab-3274263_19-5b4ce87746e0fb00370a5025.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://static.vecteezy.com/system/resources/previews/025/269/690/non_2x/kebab-with-ai-generated-free-png.png
# [!] Issue getting: https://static.vecteezy.com/system/resources/previews/025/269/690/non_2x/kebab-with-ai-generated-free-png.png
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #6 from https://kim-foods.com/wp-content/uploads/2018/07/Kebab-scaled.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #7 from https://silkroadrecipes.com/wp-content/uploads/2024/06/Turkish-Doner-Kebabs-Beef-or-Lamb-square.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #8 from https://www.savorythoughts.com/wp-content/uploads/2021/09/Doner-Kebab-Recipe-Savory-Thoughts-13.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #9 from https://image.shutterstock.com/z/stock-photo-d-ner-kebab-doner-kebap-fast-food-snack-in-flatbread-isolated-on-a-white-background-2131297619.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #10 from https://tumiasto.pl/wp-content/uploads/2024/09/kebab-meat-sandwich-7414529_1280.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #11 from https://www.thespruceeats.com/thmb/NRuxY8YJmof92GgShYoUFouVeIo=/2105x2105/filters:fill(auto,1)/aqIMG_1498fsq-5b343910c9e77c001a218bd0.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #12 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# [%] Downloading Image #13 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-slice-fast-food-flatbread-with-french-fries-wooden-board_770123-1302.jpg?w=1380
# [%] File Downloaded!
#
# [%] Downloading Image #14 from https://static01.nyt.com/images/2022/12/05/multimedia/nd-shish-kebab-1-2329/nd-shish-kebab-1-2329-threeByTwoMediumAt2X.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #15 from https://www.idgastronomic.com/wp-content/uploads/2023/01/Kebab-de-Pollo-Asado-y-Loncheado-slider.jpg
# [!] Issue getting: https://www.idgastronomic.com/wp-content/uploads/2023/01/Kebab-de-Pollo-Asado-y-Loncheado-slider.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #15 from https://turkishfoodie.com/wp-content/uploads/2019/04/Durum-Roll-Doner-Kebab.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #16 from https://www.homemademastery.com/wp-content/uploads/2022/08/lamb-doener-IMG_2122.jpg
# [!] Issue getting: https://www.homemademastery.com/wp-content/uploads/2022/08/lamb-doener-IMG_2122.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #16 from https://fussfreeflavours.com/wp-content/uploads/2022/06/Lamb-Shish-Kebab-Main.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #17 from https://static.vecteezy.com/system/resources/previews/022/007/205/large_2x/tasty-doner-kebab-shawarma-roll-wrap-illustration-generative-ai-food-photo.jpeg
# [!] Issue getting: https://static.vecteezy.com/system/resources/previews/022/007/205/large_2x/tasty-doner-kebab-shawarma-roll-wrap-illustration-generative-ai-food-photo.jpeg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #17 from https://static.independent.co.uk/s3fs-public/thumbnails/image/2019/05/21/16/kebab3.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #18 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #19 from https://turkishfoodie.com/wp-content/uploads/2018/07/Lamb-Shish-Kebab.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #20 from https://alltastesgerman.com/wp-content/uploads/2022/10/chicken-doner-kebab-recipe.jpg
# [!] Issue getting: https://alltastesgerman.com/wp-content/uploads/2022/10/chicken-doner-kebab-recipe.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #20 from https://vidarbergum.com/wp-content/uploads/2024/05/adana-kebab-4.jpg
# [!] Issue getting: https://vidarbergum.com/wp-content/uploads/2024/05/adana-kebab-4.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #20 from https://www.tuerkische-rezepte.net/wp-content/uploads/2021/09/doener-kebab.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #21 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #22 from https://static.independent.co.uk/s3fs-public/thumbnails/image/2017/12/01/16/doner-kebab-0.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #23 from https://img.freepik.com/premium-photo/traditional-delicious-turkish-foods-doner-kebab-grilled-meat_693630-9686.jpg?w=2000
# [%] File Downloaded!
#
# [%] Downloading Image #24 from https://www.homemademastery.com/wp-content/uploads/2022/08/lamb-doener-IMG_2133.jpg
# [!] Issue getting: https://www.homemademastery.com/wp-content/uploads/2022/08/lamb-doener-IMG_2133.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #24 from https://as1.ftcdn.net/v2/jpg/01/47/45/72/1000_F_147457224_odMn45V9ZdL1tdxQcOU5orCK8eNSEgbt.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #25 from https://www.tamingtwins.com/wp-content/uploads/2022/09/slow-cooker-doner-kebab-5.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #26 from https://i.ytimg.com/vi/dhl3wFDl3Rs/maxresdefault.jpg
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] No new images found, stopping.
#
#
# [%] Done. Downloaded 26 images.

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shahlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
